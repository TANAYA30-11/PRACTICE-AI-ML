# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# data frame

# %%
import numpy as np
import pandas as pd

# %%
data={
    'Name':['john','tanaya','anna','linda'],
    'Age':[28,34,27,45],
    'City':['new york','paris','berlin','london'],
    'Salary':[65000,70000,62000,85000]
}
df=pd.DataFrame(data)

# %%
# data_list=[
#     ['john','tanaya','anna','linda'],
#     [28,34,27,45],
#     ['new york','paris','berlin','london'],
#     [65000,70000,62000,85000]
# ]
# df2=pd.DataFrame(data_list)
# columns=["Name","Age","City","Salary"]
# df2=pd.DataFrame(data_list,columns= columns)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    john   28  new york   65000
# 1  tanaya   34     paris   70000
# 2    anna   27    berlin   62000
# 3   linda   45    london   85000

# %%
df[['Name','City']]
# Out:
#      Name      City
# 0    john  new york
# 1  tanaya     paris
# 2    anna    berlin
# 3   linda    london

# %%
df["Designation"]=["doctor","eng.","it","farma"]

# %%
df
# Out:
#      Name  Age      City  Salary Designation
# 0    john   28  new york   65000      doctor
# 1  tanaya   34     paris   70000        eng.
# 2    anna   27    berlin   62000          it
# 3   linda   45    london   85000       farma

# %%
df.drop("Designation",axis=1,inplace=True)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    john   28  new york   65000
# 1  tanaya   34     paris   70000
# 2    anna   27    berlin   62000
# 3   linda   45    london   85000

# %%
df.loc[[0,1]]
# Out:
#      Name  Age      City  Salary
# 0    john   28  new york   65000
# 1  tanaya   34     paris   70000

# %%
df.iloc[3]
# Out:
# Name       linda
# Age           45
# City      london
# Salary     85000
# Name: 3, dtype: object

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  new york   65000
# 1     paris   70000

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2   anna   27
# 3  linda   45

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    john   28  new york   65000
# 1  tanaya   34     paris   70000
# 2    anna   27    berlin   62000
# 3   linda   45    london   85000

# %%
#above 30 ages
df[df["Age"]>30]
# Out:
#      Name  Age    City  Salary
# 1  tanaya   34   paris   70000
# 3   linda   45  london   85000

# %%
#above 30 ages and city are paris
df[(df["Age"]>30) & (df["City"]=="paris")]
# Out:
#      Name  Age   City  Salary
# 1  tanaya   34  paris   70000

# %%
import numpy as np
import pandas as pd

# %%
data={
    'A':[1,2,np.nan,4,5],
    'B':[1,2,3,4,5],
    'C':[1,2,3,np.nan,np.nan],
    'D':[1,np.nan,np.nan,np.nan,5]
}
fd=pd.DataFrame(data)

# %%
fd
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
fd.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
fd.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
fd.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
fd
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
fd.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
fd.dropna(thresh=3)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %%
fd.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values={'A':0,'B':100,'C':200,'D':300}
fd.fillna(value=values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  300.0
# 2  0.0  3    3.0  300.0
# 3  4.0  4  200.0  300.0
# 4  5.0  5  200.0    5.0

# %%
fd.fillna(fd.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0
